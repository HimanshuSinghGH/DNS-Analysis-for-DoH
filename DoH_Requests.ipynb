# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.common.exceptions import TimeoutException , WebDriverException
from time import sleep,ctime
from selenium.webdriver.common.by import By

# %%
df = pd.read_csv('top-1m.csv' , names=['rank','website'])

site_df = df.iloc[150:200]

print(site_df)
# Out:
#      rank             website
# 150   151       mediafire.com
# 151   152            avito.ru
# 152   153            cnet.com
# 153   154       google.com.sg
# 154   155           globo.com
# 155   156       xinhuanet.com
# 156   157         openload.co
# 157   158         spotify.com
# 158   159        flipkart.com
# 159   160        ladbible.com
# 160   161       google.com.ph
# 161   162       google.com.co
# 162   163         popcash.net
# 163   164           google.be
# 164   165           google.se
# 165   166      deviantart.com
# 166   167           zhihu.com
# 167   168           google.cn
# 168   169          roblox.com
# 169   170           github.io
# 170   171         walmart.com
# 171   172           google.az
# 172   173           douyu.com
# 173   174          uol.com.br
# 174   175           force.com
# 175   176      slideshare.net
# 176   177         upornia.com
# 177   178         wikihow.com
# 178   179            yelp.com
# 179   180           twimg.com
# 180   181   daikynguyenvn.com
# 181   182       w3schools.com
# 182   183  washingtonpost.com
# 183   184        china.com.cn
# 184   185          pinimg.com
# 185   186         godaddy.com
# 186   187            etsy.com
# 187   188          rambler.ru
# 188   189         alibaba.com
# 189   190           sogou.com
# 190   191             nih.gov
# 191   192           google.at
# 192   193          hclips.com
# 193   194        softonic.com
# 194   195        babytree.com
# 195   196         redtube.com
# 196   197       google.com.ng
# 197   198  iwanttodeliver.com
# 198   199            9gag.com
# 199   200           slack.com

# %%
site_df.insert(2, "raw_dns", int(0)) 
site_df.insert(3, "final_dns", int(0)) 
print(site_df)
# Out:
#      rank             website  raw_dns  final_dns
# 150   151       mediafire.com        0          0
# 151   152            avito.ru        0          0
# 152   153            cnet.com        0          0
# 153   154       google.com.sg        0          0
# 154   155           globo.com        0          0
# 155   156       xinhuanet.com        0          0
# 156   157         openload.co        0          0
# 157   158         spotify.com        0          0
# 158   159        flipkart.com        0          0
# 159   160        ladbible.com        0          0
# 160   161       google.com.ph        0          0
# 161   162       google.com.co        0          0
# 162   163         popcash.net        0          0
# 163   164           google.be        0          0
# 164   165           google.se        0          0
# 165   166      deviantart.com        0          0
# 166   167           zhihu.com        0          0
# 167   168           google.cn        0          0
# 168   169          roblox.com        0          0
# 169   170           github.io        0          0
# 170   171         walmart.com        0          0
# 171   172           google.az        0          0
# 172   173           douyu.com        0          0
# 173   174          uol.com.br        0          0
# 174   175           force.com        0          0
# 175   176      slideshare.net        0          0
# 176   177         upornia.com        0          0
# 177   178         wikihow.com        0          0
# 178   179            yelp.com        0          0
# 179   180           twimg.com        0          0
# 180   181   daikynguyenvn.com        0          0
# 181   182       w3schools.com        0          0
# 182   183  washingtonpost.com        0          0
# 183   184        china.com.cn        0          0
# 184   185          pinimg.com        0          0
# 185   186         godaddy.com        0          0
# 186   187            etsy.com        0          0
# 187   188          rambler.ru        0          0
# 188   189         alibaba.com        0          0
# 189   190           sogou.com        0          0
# 190   191             nih.gov        0          0
# 191   192           google.at        0          0
# 192   193          hclips.com        0          0
# 193   194        softonic.com        0          0
# 194   195        babytree.com        0          0
# 195   196         redtube.com        0          0
# 196   197       google.com.ng        0          0
# 197   198  iwanttodeliver.com        0          0
# 198   199            9gag.com        0          0
# 199   200           slack.com        0          0

# %%
def get_domains() :
    domains = set()
    table_id =driver.find_element(By.ID, 'dns_content')
    rows = table_id.find_elements(By.TAG_NAME, "tr")
    for row in rows :
        col = row.find_elements(By.TAG_NAME, "td")[0]
        #domains.add(col.text)
        print(col.text)
    print(len(domains))

# %%
firefox_domains = ["ocsp.digicert.com" , "shavar.services.mozilla.com", "push.services.mozilla.com",
                   "tracking-protection.cdn.mozilla.net","location.services.mozilla.com",
                   "detectportal.firefox.com" ,"snippets.cdn.mozilla.net" ]
def open_website(url,count):
    print(count)
    print(url)
    domains = set()
    final_domains = set()
    try :
        driver = webdriver.Firefox()
        driver.set_page_load_timeout(60)
        driver.get(url)
        sleep(2)
        driver.get("about:networking#dns")
        sleep(2)
        table_id =driver.find_element(By.ID, 'dns_content')
        rows = table_id.find_elements(By.TAG_NAME, "tr")
        for row in rows :
            col = row.find_elements(By.TAG_NAME, "td")[0]
            domains.add(col.text)
            print(col.text)
            if not col.text in firefox_domains :
                final_domains.add(col.text)
        print(len(domains))
        print(len(final_domains))
        raw_dns = int(len(domains))
        final_dns = int(len(final_domains))
        site_df.at[count-1 , 'raw_dns'] = raw_dns
        site_df.at[count-1 , 'final_dns'] = final_dns
        sleep(2)
        #driver.close()
    except TimeoutException as ex1:
        print("Exception has been thrown. " + str(ex1))
        driver.get("about:networking#dns")
        sleep(2)
        table_id =driver.find_element(By.ID, 'dns_content')
        rows = table_id.find_elements(By.TAG_NAME, "tr")
        for row in rows :
            col = row.find_elements(By.TAG_NAME, "td")[0]
            domains.add(col.text)
            print(col.text)
            if not col.text in firefox_domains :
                final_domains.add(col.text)
        print(len(domains))
        print(len(final_domains))
        raw_dns = int(len(domains))
        final_dns = int(len(final_domains))
        site_df.at[count-1 , 'raw_dns'] = raw_dns
        site_df.at[count-1 , 'final_dns'] = final_dns
        sleep(2)
        #driver.close()
    except WebDriverException as ex2:
        print("Exception has been thrown. " + str(ex2))
        driver.get("about:networking#dns")
        sleep(2)
        table_id =driver.find_element(By.ID, 'dns_content')
        rows = table_id.find_elements(By.TAG_NAME, "tr")
        for row in rows :
            col = row.find_elements(By.TAG_NAME, "td")[0]
            domains.add(col.text)
            print(col.text)
            if not col.text in firefox_domains :
                final_domains.add(col.text)
        print(len(domains))
        print(len(final_domains))
        raw_dns = int(len(domains))
        final_dns = int(len(final_domains))
        site_df.at[count-1 , 'raw_dns'] = raw_dns
        site_df.at[count-1 , 'final_dns'] = final_dns
        sleep(2)
        #driver.close()
    driver.close()

# %%
count = 151
for domain in site_df['website'] :
    url = 'http://www.'+domain
    open_website(url,count)
    count = count+1

#open_website("http://www.google.com")
# Out:
# 151
# http://www.mediafire.com
# ocsp.digicert.com
# static.hotjar.com
# ocsp.pki.goog
# script.hotjar.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# ocsp.pki.goog
# pixel.quantserve.com
# push.services.mozilla.com
# www.gstatic.com
# www.google-analytics.com
# ocsp.digicert.com
# www.gstatic.com
# ocsp.digicert.com
# fonts.gstatic.com
# connect.facebook.net
# ocsp.int-x3.letsencrypt.org
# script.hotjar.com
# static.mediafire.com
# fonts.googleapis.com
# vars.hotjar.com
# secure.quantserve.com
# rules.quantcount.com
# www.googletagmanager.com
# www.google.co.in
# shavar.services.mozilla.com
# static.hotjar.com
# vars.hotjar.com
# snippets.cdn.mozilla.net
# www.mediafire.com
# www.facebook.com
# www.google.com
# tracking-protection.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# location.services.mozilla.com
# ocsp.int-x3.letsencrypt.org
# stats.g.doubleclick.net
# ajax.googleapis.com
# 28
# 21
# 152
# http://www.avito.ru
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# yastatic.net
# www.googleadservices.com
# sb.scorecardresearch.com
# ocsp.pki.goog
# yandex.ocsp-responder.com
# static.criteo.net
# an.yandex.ru
# ads.adfox.ru
# www.google-analytics.com
# ocsp.digicert.com
# sslwidget.criteo.com
# 09.img.avito.st
# ads.adfox.ru
# ocsp.digicert.com
# www.avito.st
# connect.facebook.net
# 65.img.avito.st
# dnacdn.net
# mc.yandex.ru
# awaps.yandex.ru
# ocsp.pki.goog
# ag.gbc.criteo.com
# matchid.adfox.yandex.ru
# 10.img.avito.st
# matchid.adfox.yandex.ru
# yandex.ocsp-responder.com
# sslwidget.criteo.com
# yandex.ru
# stats.g.doubleclick.net
# www.google.com
# csm.hk.as.criteo.net
# widget.eu.criteo.com
# 52.img.avito.st
# avatars.mds.yandex.net
# avatars.mds.yandex.net
# www.tns-counter.ru
# mc.yandex.ru
# 48.img.avito.st
# yastatic.net
# gum.criteo.com
# 31
# 30
# 153
# http://www.cnet.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# tpc.googlesyndication.com
# ocsp.digicert.com
# securepubads.g.doubleclick.net
# status.thawte.com
# status.thawte.com
# mid.rkdms.com
# ocsp.sectigo.com
# cnet3.cbsistatic.com
# sb.scorecardresearch.com
# sofia.trustx.org
# adserver-us.adtech.advertising.com
# www.googletagservices.com
# ocsp.digicert.com
# cnet1.cbsistatic.com
# www.cnet.com
# static.chartbeat.com
# ocsp.digicert.com
# c.amazon-adsystem.com
# www.cnet.com
# ib.adnxs.com
# z.moatads.com
# mab.chartbeat.com
# apex.go.sonobi.com
# match.adsrvr.org
# cbsi-d.openx.net
# ocsp.entrust.net
# ads.rubiconproject.com
# cnet4.cbsistatic.com
# ocsp.sectigo.com
# ping.chartbeat.net
# mid.rkdms.com
# ping.chartbeat.net
# pagead2.googlesyndication.com
# s0.2mdn.net
# cnet2.cbsistatic.com
# geo.moatads.com
# gum.criteo.com
# as-sec.casalemedia.com
# ocsp.trustwave.com
# api.rlcdn.com
# geo.moatads.com
# snippets.cdn.mozilla.net
# gum.criteo.com
# native.sharethrough.com
# z.moatads.com
# tracking-protection.cdn.mozilla.net
# adservice.google.co.in
# match.adsrvr.org
# c.go-mpulse.net
# cnet2.cbsistatic.com
# c.go-mpulse.net
# adservice.google.com
# cnet3.cbsistatic.com
# cnet1.cbsistatic.com
# cnet4.cbsistatic.com
# js-sec.indexww.com
# px.moatads.com
# 41
# 38
# 154
# http://www.google.com.sg
# www.google.com.sg
# push.services.mozilla.com
# ocsp.pki.goog
# www.gstatic.com
# ocsp.digicert.com
# ssl.gstatic.com
# push.services.mozilla.com
# snippets.cdn.mozilla.net
# adservice.google.com.sg
# apis.google.com
# 9
# 6
# 155
# http://www.globo.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# securepubads.g.doubleclick.net
# push.services.mozilla.com
# sb.scorecardresearch.com
# cdn.jsdelivr.net
# push.services.mozilla.com
# ocsp.digicert.com
# status.rapidssl.com
# www.globo.com
# ocsp.digicert.com
# www.globo.com
# s3.glbimg.com
# s3.glbimg.com
# ocsp.pki.goog
# snippets.cdn.mozilla.net
# 10
# 7
# 156
# http://www.xinhuanet.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.xinhuanet.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.xinhuanet.com.
#
# push.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# location.services.mozilla.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# 4
# 0
# 157
# http://www.openload.co
# push.services.mozilla.com
# www.openload.co
# push.services.mozilla.com
# www.openload.co
# ocsp.digicert.com
# ocsp.digicert.com
# www.airtel.in
# www.airtel.in
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# 7
# 2
# 158
# http://www.spotify.com
# tracking-protection.cdn.mozilla.net
# 1
# 0
# 159
# http://www.flipkart.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# push.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# detectportal.firefox.com
# 5
# 0
# 160
# http://www.ladbible.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.ladbible.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.ladbible.com.
#
# location.services.mozilla.com
# push.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# 4
# 0
# 161
# http://www.google.com.ph
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.pki.goog
# tracking-protection.cdn.mozilla.net
# detectportal.firefox.com
# www.google.com.ph
# 4
# 2
# 162
# http://www.google.com.co
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# adservice.google.com.co
# www.google.com.co
# ocsp.pki.goog
# ssl.gstatic.com
# shavar.services.mozilla.com
# apis.google.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# ogs.google.com
# location.services.mozilla.com
# www.gstatic.com
# 14
# 7
# 163
# http://www.popcash.net
# www.popcash.net
# www.google-analytics.com
# linkedin.com
# tracking-protection.cdn.mozilla.net
# facebook.com
# www.facebook.com
# twitter.com
# members.popcash.net
# www.linkedin.com
# s2.cdnpc.net
# www.instagram.com
# s2.cdnpc.net
# 11
# 10
# 164
# http://www.google.be
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# ocsp.digicert.com
# www.google.be
# ocsp.pki.goog
# ocsp.digicert.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# 7
# 2
# 165
# http://www.google.se
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# ocsp.pki.goog
# www.google.se
# ssl.gstatic.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# 9
# 3
# 166
# http://www.deviantart.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.sectigo.com
# pixel.quantserve.com
# ocsp.godaddy.com
# images-wixmp-ed30a86b8c4ca887773594c2.wixmp.com
# ocsp.godaddy.com
# 4
# 4
# 167
# http://www.zhihu.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.zhihu.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.zhihu.com.
#
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# ocsp.digicert.com
# ocsp.digicert.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# 6
# 0
# 168
# http://www.google.cn
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# www.google.com.hk
# ocsp.digicert.com
# www.google.cn
# www.google.cn
# translate.google.cn
# shavar.services.mozilla.com
# push.services.mozilla.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# detectportal.firefox.com
# location.services.mozilla.com
# 10
# 3
# 169
# http://www.roblox.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# push.services.mozilla.com
# www.roblox.com
# static.rbxcdn.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# www.roblox.com
# detectportal.firefox.com
# 6
# 2
# 170
# http://www.github.io
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# shavar.services.mozilla.com
# 1
# 0
# 171
# http://www.walmart.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# location.services.mozilla.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# i5.walmartimages.com
# location.services.mozilla.com
# 4
# 1
# 172
# http://www.google.az
# shavar.services.mozilla.com
# ocsp.pki.goog
# www.google.az
# adservice.google.com
# ssl.gstatic.com
# shavar.services.mozilla.com
# apis.google.com
# adservice.google.az
# location.services.mozilla.com
# detectportal.firefox.com
# ogs.google.com
# www.gstatic.com
# 11
# 8
# 173
# http://www.douyu.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.douyu.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.douyu.com.
#
# ocsp.digicert.com
# detectportal.firefox.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# location.services.mozilla.com
# 4
# 0
# 174
# http://www.uol.com.br
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# securepubads.g.doubleclick.net
# ocsp.pki.goog
# stc.uol.com
# conteudo.jsuol.com.br
# www.uol.com.br
# static.chartbeat.com
# ocsp.comodoca4.com
# location.services.mozilla.com
# tm.jsuol.com.br
# me.jsuol.com.br
# me.jsuol.com.br
# shavar.services.mozilla.com
# ocsp.sca1b.amazontrust.com
# stc.uol.com
# detectportal.firefox.com
# adservice.google.com
# 14
# 11
# 175
# http://www.force.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# logx.optimizely.com
# push.services.mozilla.com
# logx.optimizely.com
# ocsp.pki.goog
# push.services.mozilla.com
# www.google-analytics.com
# ocsp.digicert.com
# d.la1-c2-phx.salesforceliveagent.com
# omtr2.partners.salesforce.com
# ocsp.digicert.com
# p.adsymptotic.com
# connect.facebook.net
# d.la1-c2-phx.salesforceliveagent.com
# org62.my.salesforce.com
# www.facebook.com
# trc.taboola.com
# t.co
# googleads.g.doubleclick.net
# www.google.co.in
# org62.my.salesforce.com
# s.adroll.com
# www.google.co.in
# www.linkedin.com
# beacon.krxd.net
# snippets.cdn.mozilla.net
# px.ads.linkedin.com
# www.google.com
# tracking-protection.cdn.mozilla.net
# bat.bing.com
# dc.ads.linkedin.com
# ct.capterra.com
# detectportal.firefox.com
# ct.capterra.com
# static.ads-twitter.com
# beacon.krxd.net
# sjs.bizographics.com
# stats.g.doubleclick.net
# www.linkedin.com
# 29
# 24
# 176
# http://www.slideshare.net
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.slideshare.net/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.slideshare.net.
#
# shavar.services.mozilla.com
# ocsp.digicert.com
# shavar.services.mozilla.com
# location.services.mozilla.com
# 3
# 0
# 177
# http://www.upornia.com
# ocsp.digicert.com
# securepubads.g.doubleclick.net
# c.adskeeper.co.uk
# static1.upornia.org
# static2.upornia.org
# push.services.mozilla.com
# shavar.services.mozilla.com
# www.google-analytics.com
# ocsp.pki.goog
# www.googletagmanager.com
# push.services.mozilla.com
# www.googletagservices.com
# www.google-analytics.com
# ocsp.digicert.com
# native.wpu.sh
# location.services.mozilla.com
# script.bangdom.com
# fonts.gstatic.com
# cdn60563788.ahacdn.me
# s-img.adskeeper.co.uk
# kts.visitstats.com
# cdn60563788.ahacdn.me
# mc.yandex.ru
# kts.visitstats.com
# static1.upornia.org
# upornia.com
# fonts.googleapis.com
# events.tubecup.org
# upornia.com
# shavar.services.mozilla.com
# www.googletagmanager.com
# sw.wpu.sh
# static2.upornia.org
# 12111549.pix-cdn.org
# static3.upornia.org
# mc.yandex.ru
# 12111549.pix-cdn.org
# ocsp.comodoca.com
# snippets.cdn.mozilla.net
# static3.upornia.org
# lindenlaugh.pro
# stats.g.doubleclick.net
# tracking-protection.cdn.mozilla.net
# adservice.google.co.in
# ocsp.comodoca.com
# sw.wpu.sh
# location.services.mozilla.com
# cdn35854568.ahacdn.me
# ocsp.int-x3.letsencrypt.org
# detectportal.firefox.com
# cdn.user-api.com
# iconcnd.co
# adservice.google.com
# ads.exoclick.com
# native.wpu.sh
# fonts.gstatic.com
# ocsp.int-x3.letsencrypt.org
# www.upornia.com
# 39
# 32
# 178
# http://www.wikihow.com
# ocsp.pki.goog
# www.google-analytics.com
# connect.facebook.net
# staticxx.facebook.com
# ocsp.digicert.com
# hosted-sip.civic.com
# tracking-protection.cdn.mozilla.net
# ssl.gstatic.com
# www.facebook.com
# stats.g.doubleclick.net
# accounts.google.com
# apis.google.com
# www.wikihow.com
# 13
# 11
# 179
# http://www.yelp.com
# ocsp.digicert.com
# www.googleadservices.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# ocsp.pki.goog
# googleads.g.doubleclick.net
# push.services.mozilla.com
# www.yelp.com
# www.google-analytics.com
# ocsp.digicert.com
# ocsp.comodoca4.com
# promos.yelpcdn.com
# ocsp.comodoca4.com
# location.services.mozilla.com
# s3-media0.fl.yelpcdn.com
# s3-media1.fl.yelpcdn.com
# s3-media1.fl.yelpcdn.com
# s3-media4.fl.yelpcdn.com
# cdnjs.cloudflare.com
# www.google.co.in
# 6372968.fls.doubleclick.net
# shavar.services.mozilla.com
# s3-media2.fl.yelpcdn.com
# snippets.cdn.mozilla.net
# stats.g.doubleclick.net
# tracking-protection.cdn.mozilla.net
# adservice.google.co.in
# s3-media2.fl.yelpcdn.com
# s3-media4.fl.yelpcdn.com
# www.google.com
# detectportal.firefox.com
# adservice.google.com
# s3-media3.fl.yelpcdn.com
# s3-media3.fl.yelpcdn.com
# 26
# 19
# 180
# http://www.twimg.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.twimg.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.twimg.com.
#
# shavar.services.mozilla.com
# ocsp.digicert.com
# shavar.services.mozilla.com
# detectportal.firefox.com
# location.services.mozilla.com
# 4
# 0
# 181
# http://www.daikynguyenvn.com
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# ocsp.pki.goog
# push.services.mozilla.com
# www.daikynguyenvn.com
# www.google-analytics.com
# ocsp.digicert.com
# ocsp.digicert.com
# www.google.com
# fonts.gstatic.com
# connect.facebook.net
# staticxx.facebook.com
# netdna.bootstrapcdn.com
# cdnjs.cloudflare.com
# fonts.googleapis.com
# www.google.co.in
# www.daikynguyenvn.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# www.facebook.com
# stats.g.doubleclick.net
# tracking-protection.cdn.mozilla.net
# video2.dkn.tv
# location.services.mozilla.com
# detectportal.firefox.com
# location.services.mozilla.com
# ajax.googleapis.com
# 22
# 15
# 182
# http://www.w3schools.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# pr-bh.ybp.yahoo.com
# status.geotrust.com
# acdn.adnxs.com
# us-u.openx.net
# static.criteo.net
# cr-p3.ladsp.jp
# ocsp2.globalsign.com
# dps.jp.cinarra.com
# ocsp.digicert.com
# ad.turn.com
# ocsp.godaddy.com
# secure.adnxs.com
# secure.adnxs.com
# secure-assets.rubiconproject.com
# ib.adnxs.com
# image4.pubmatic.com
# ocsp.godaddy.com
# match.adsrvr.org
# simage2.pubmatic.com
# x.bidswitch.net
# cr-pall.ladsp.com
# sync.mathtag.com
# ocsp.sectigo.com
# sync.1rx.io
# u.openx.net
# sync.mathtag.com
# simage2.pubmatic.com
# cookie.brealtime.com
# image6.pubmatic.com
# pixel.quantserve.com
# ocsp.trustwave.com
# sync-tm.everesttech.net
# pippio.com
# ocsp.trustwave.com
# s.amazon-adsystem.com
# ocsp.sca1b.amazontrust.com
# a.tribalfusion.com
# pm.w55c.net
# jp-u.openx.net
# simage4.pubmatic.com
# image2.pubmatic.com
# sync-dsp.ad-m.asia
# ads.pubmatic.com
# s.amazon-adsystem.com
# c1.adform.net
# tg.socdm.com
# cm.g.doubleclick.net
# ib.adnxs.com
# ocsp.comodoca.com
# idsync.rlcdn.com
# x.bidswitch.net
# rtb.gumgum.com
# 44
# 43
# 183
# http://www.washingtonpost.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# 0
# 0
# 184
# http://www.china.com.cn
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.china.com.cn/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.china.com.cn.
#
# shavar.services.mozilla.com
# push.services.mozilla.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# tracking-protection.cdn.mozilla.net
# detectportal.firefox.com
# 5
# 0
# 185
# http://www.pinimg.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# detectportal.firefox.com
# 1
# 0
# 186
# http://www.godaddy.com
# in.godaddy.com
# www.google-analytics.com
# ocsp.pki.goog
# img1.wsimg.com
# img1.wsimg.com
# events.godaddy.com
# tags.tiqcdn.com
# www.youtube.com
# gui.godaddy.com
# www.googletagmanager.com
# www.godaddy.com
# 10
# 10
# 187
# http://www.etsy.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.etsy.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.etsy.com.
#
# ocsp.digicert.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# ocsp.digicert.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# location.services.mozilla.com
# detectportal.firefox.com
# location.services.mozilla.com
# 6
# 0
# 188
# http://www.rambler.ru
# ocsp.pki.goog
# static.rnet.plus
# storage.googleapis.com
# 3
# 3
# 189
# http://www.alibaba.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
# ocsp.digicert.com
# open-s.alibaba.com
# fourier.taobao.com
# fourier.taobao.com
# push.services.mozilla.com
# ocsp2.globalsign.com
# img.alicdn.com
# www.alibaba.com
# push.services.mozilla.com
# ocsp2.globalsign.com
# ocsp.digicert.com
# acs.h.alibaba.com
# aeis.alicdn.com
# detectportal.firefox.com
# us.ynuf.aliapp.org
# s.alicdn.com
# stun.services.mozilla.com
# assets.alicdn.com
# cyl2rf.tdum.alibaba.com
# us.ynuf.aliapp.org
# tracking-protection.cdn.mozilla.net
# cyl2rf.tdum.alibaba.com
# snippets.cdn.mozilla.net
# g.alicdn.com
# open-s.alibaba.com
# marketing.alibaba.com
# i.alicdn.com
# marketing.alibaba.com
# acs.h.alibaba.com
# 20
# 15
# 190
# http://www.sogou.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.sogou.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.sogou.com.
#
# 0
# 0
# 191
# http://www.nih.gov
# ocsp.digicert.com
# ocsp.pki.goog
# search.usa.gov
# s.ytimg.com
# shavar.services.mozilla.com
# ocsp.pki.goog
# search.usa.gov
# push.services.mozilla.com
# www.google-analytics.com
# ocsp.digicert.com
# push.services.mozilla.com
# ocsp.digicert.com
# fonts.gstatic.com
# www.youtube.com
# cdn.jsdelivr.net
# shavar.services.mozilla.com
# fonts.googleapis.com
# script.crazyegg.com
# js.api.here.com
# www.nih.gov
# www.nih.gov
# stats.g.doubleclick.net
# detectportal.firefox.com
# ocsp.int-x3.letsencrypt.org
# 17
# 13
# 192
# http://www.google.at
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# detectportal.firefox.com
# www.google.at
# 2
# 1
# 193
# http://www.hclips.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.hclips.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.hclips.com.
#
# ocsp.digicert.com
# shavar.services.mozilla.com
# ocsp.digicert.com
# shavar.services.mozilla.com
# detectportal.firefox.com
# location.services.mozilla.com
# 4
# 0
# 194
# http://www.softonic.com
# widget.us.criteo.com
# ocsp.sectigo.com
# pbs.twimg.com
# token.rubiconproject.com
# prebid-eu.creativecdn.com
# prebid-eu.creativecdn.com
# tpc.googlesyndication.com
# a.optnmstr.com
# securepubads.g.doubleclick.net
# pr-bh.ybp.yahoo.com
# ocsp.pki.goog
# pbs.twimg.com
# adservice.google.co.in
# static.criteo.net
# fonts.gstatic.com
# cloud.setupad.com
# ocsp.sectigo.com
# secure-assets.rubiconproject.com
# acdn.adnxs.com
# sb.scorecardresearch.com
# a.optnmstr.com
# ocsp.pki.goog
# status.thawte.com
# static.criteo.net
# node.setupad.com
# login.softonic.com
# detectportal.firefox.com
# gum.criteo.com
# www.googletagservices.com
# node.setupad.com
# www.google-analytics.com
# ocsp.digicert.com
# hbopenbid.pubmatic.com
# bidder.criteo.com
# pixel.rubiconproject.com
# widget.us.criteo.com
# ocsp.godaddy.com
# pixel.rubiconproject.com
# id.rlcdn.com
# ocsp.digicert.com
# dmx.districtm.io
# static.simonsignal.com
# secure.adnxs.com
# status.rapidssl.com
# c.amazon-adsystem.com
# solutions-assets.sftcdn.net
# connect.facebook.net
# amplifypixel.outbrain.com
# dnacdn.net
# ib.adnxs.com
# amplifypixel.outbrain.com
# b-code.liadm.com
# ads.betweendigital.com
# pixel-us-east.rubiconproject.com
# api.opmnstr.com
# c.liadm.com
# images.sftcdn.net
# amplify.outbrain.com
# match.adsrvr.org
# eus.rubiconproject.com
# ampcid.google.co.in
# x.bidswitch.net
# ag.gbc.criteo.com
# sync.mathtag.com
# tr.outbrain.com
# x.bidswitch.net
# prg.smartadserver.com
# cdn.syndication.twimg.com
# token.rubiconproject.com
# dnacdn.net
# cm.g.doubleclick.net
# pixel-us-east.rubiconproject.com
# ap.lijit.com
# www.googletagmanager.com
# googleads.g.doubleclick.net
# sync.mathtag.com
# scontent.fbho3-1.fna.fbcdn.net
# en.softonic.com
# cdns.gigya.com
# articles-images.sftcdn.net
# i.liadm.com
# login.softonic.com
# syndication.twitter.com
# articles-images.sftcdn.net
# sslwidget.criteo.com
# i.liadm.com
# ap.lijit.com
# sync-tm.everesttech.net
# sslwidget.criteo.com
# as-sec.casalemedia.com
# ocsp.trustwave.com
# s.amazon-adsystem.com
# prg.smartadserver.com
# ocsp.sca1b.amazontrust.com
# c.liadm.com
# status.rapidssl.com
# ampcid.google.com
# fastlane.rubiconproject.com
# bidder.criteo.com
# gum.criteo.com
# x.dlx.addthis.com
# platform.twitter.com
# www.facebook.com
# fastlane.rubiconproject.com
# stats.g.doubleclick.net
# cdn.ampproject.org
# www.google.com
# ocsp.godaddy.com
# id.sharedid.org
# beacon.walmart.com
# sc.sftcdn.net
# www.google.co.in
# s.amazon-adsystem.com
# match.adsrvr.org
# id.sharedid.org
# ton.twimg.com
# adx.adform.net
# hb.emxdgt.com
# simonsignal.com
# ocsp.int-x3.letsencrypt.org
# ib.adnxs.com
# platform.twitter.com
# adservice.google.com
# api.opmnstr.com
# gem.gbc.criteo.com
# dpm.demdex.net
# cdns.eu1.gigya.com
# staticxx.facebook.com
# x.dlx.addthis.com
# ocsp.int-x3.letsencrypt.org
# csm.hk.as.criteo.net
# syndication.twitter.com
# images.sftcdn.net
# fonts.googleapis.com
# ag.gbc.criteo.com
# 96
# 94
# 195
# http://www.babytree.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.digicert.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# push.services.mozilla.com
# aimg.babytreeimg.com
# ocsp.digicert.com
# ocsp.digicert.com
# www.babytree.com
# www.babytree.com
# pic.babytree.com
# shavar.services.mozilla.com
# snippets.cdn.mozilla.net
# pic.babytree.com
# location.services.mozilla.com
# detectportal.firefox.com
# g.kexin001.com
# g.kexin001.com
# aimg.babytreeimg.com
# 10
# 4
# 196
# http://www.redtube.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.redtube.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.redtube.com.
#
# 0
# 0
# 197
# http://www.google.com.ng
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.digicert.com
# www.google.com.ng
# ocsp.digicert.com
# detectportal.firefox.com
# ssl.gstatic.com
# www.gstatic.com
# detectportal.firefox.com
# 5
# 3
# 198
# http://www.iwanttodeliver.com
# Exception has been thrown. Message: Reached error page: about:neterror?e=dnsNotFound&u=http%3A//www.iwanttodeliver.com/&c=UTF-8&f=regular&d=We%20can%E2%80%99t%20connect%20to%20the%20server%20at%20www.iwanttodeliver.com.
#
# 0
# 0
# 199
# http://www.9gag.com
# tpc.googlesyndication.com
# ap.lijit.com
# sb.scorecardresearch.com
# video-ads.rubiconproject.com
# capi.connatix.com
# dmx.districtm.io
# aa.agkn.com
# www.googletagservices.com
# pubads.g.doubleclick.net
# ash.creativecdn.com
# status.rapidssl.com
# stats.aws.rubiconproject.com
# ocsp.godaddy.com
# www.google.com
# ocsp.digicert.com
# vid.pubmatic.com
# ib.adnxs.com
# imasdk.googleapis.com
# stats.aws.rubiconproject.com
# x.bidswitch.net
# status.geotrust.com
# cm.g.doubleclick.net
# optimized-by.rubiconproject.com
# googleads.g.doubleclick.net
# aa.agkn.com
# pagead2.googlesyndication.com
# odr.mookie1.com
# e.deployads.com
# e.deployads.com
# ash.creativecdn.com
# dt.adsafeprotected.com
# fastlane.rubiconproject.com
# rtb.openx.net
# ocsp.godaddy.com
# adservice.google.co.in
# securepubads.g.doubleclick.net
# adservice.google.com
# ssum-sec.casalemedia.com
# web-t.9gag.com
# 34
# 33
# 200
# http://www.slack.com
# Exception has been thrown. Message: Timeout loading page after 60000ms
#
# ocsp.sectigo.com
# ocsp.digicert.com
# di.rlcdn.com
# s.yjtag.jp
# ocsp.pki.goog
# www.google.co.in
# logx.optimizely.com
# push.services.mozilla.com
# shavar.services.mozilla.com
# cdn3.optimizely.com
# ocsp.pki.goog
# px.ads.linkedin.com
# slack.com
# push.services.mozilla.com
# www.google-analytics.com
# googleads.g.doubleclick.net
# ocsp.digicert.com
# px.spiceworks.com
# www.linkedin.com
# ocsp.digicert.com
# s.ytimg.com
# ad.atdmt.com
# connect.facebook.net
# secure.quantserve.com
# detectportal.firefox.com
# www.youtube.com
# reveal.clearbit.com
# detectportal.firefox.com
# tapi.optimizely.com
# rules.quantcount.com
# www.googletagmanager.com
# tapi.optimizely.com
# a.slack-edge.com
# a11179690159.cdn.optimizely.com
# pixel.quantserve.com
# cdn.optimizely.com
# shavar.services.mozilla.com
# snap.licdn.com
# 6321597.fls.doubleclick.net
# ocsp.sca1b.amazontrust.com
# snippets.cdn.mozilla.net
# www.facebook.com
# px.ads.linkedin.com
# stats.g.doubleclick.net
# www.google.com
# tracking-protection.cdn.mozilla.net
# adservice.google.co.in
# bat.bing.com
# location.services.mozilla.com
# yjtag.yahoo.co.jp
# www.linkedin.com
# adservice.google.com
# ad.doubleclick.net
# location.services.mozilla.com
# www.slack.com
# s.ytimg.com
# p.adsymptotic.com
# logx.optimizely.com
# 46
# 39

# %%
print(site_df)
# Out:
#      rank             website  raw_dns  final_dns
# 100   101            soso.com        1          1
# 101   102       google.com.sa        6          2
# 102   103        savefrom.net       14          7
# 103   104        amazon.co.uk       13          8
# 104   105             bbc.com        2          0
# 105   106             fc2.com        9          4
# 106   107         mozilla.org        3          0
# 107   108       rakuten.co.jp       36         29
# 108   109        uptodown.com        3          1
# 109   110             cnn.com       18         11
# 110   111              so.com        5          0
# 111   112      soundcloud.com       19         15
# 112   113       google.com.ua       16          9
# 113   114           quora.com        1          1
# 114   115       amazonaws.com        7          0
# 115   116             ask.com        7          5
# 116   117      clicksgear.com        5          1
# 117   118            xnxx.com        4          0
# 118   119           google.nl        7          5
# 119   120         nytimes.com       61         57
# 120   121           naver.com        3          0
# 121   122         ettoday.net       50         49
# 122   123              adf.ly        7          2
# 123   124     dailymotion.com       31         26
# 124   125       onlinesbi.com        8          1
# 125   126        google.co.za       13          6
# 126   127  steamcommunity.com        3          2
# 127   128        google.co.ve       12          6
# 128   129      salesforce.com       46         39
# 129   130            espn.com       45         41
# 130   131           fbcdn.net       15          9
# 131   132   stackexchange.com        5          0
# 132   133         blogger.com        1          0
# 133   134           chase.com        6          0
# 134   135        google.co.kr        4          4
# 135   136             ebay.de       13          6
# 136   137           vimeo.com        9          7
# 137   138            vice.com       35         30
# 138   139     theguardian.com       10          6
# 139   140    blastingnews.com        1          0
# 140   141      tribunnews.com       14         10
# 141   142    steampowered.com        4          1
# 142   143      chaturbate.com        0          0
# 143   144          ebay.co.uk        5          4
# 144   145           detik.com        6          5
# 145   146           google.gr       13          9
# 146   147       google.com.vn       10          8
# 147   148        buzzfeed.com       44         37
# 148   149          indeed.com        4          1
# 149   150     dailymail.co.uk        4          0

# %%
site_df.to_csv('151-200.csv', header=False, index=False)
